# %%
import cv2
circle_img = cv2.imread("circle.jpg")
concentric_circles_img = cv2.imread("concentric_circles.jpg")
parliament_clock_img = cv2.imread("parliament_clock.jpg") # initializing all the image variables

# %%
def upper_threshold(x):
    pass

def lower_threshold(x):
    pass

def getUpperThreshold():
    return int(cv2.getTrackbarPos('𝜏1', "Canny Edge Detection"))

def getLowerThreshold():
    return int(cv2.getTrackbarPos('𝜏2', "Canny Edge Detection"))

cv2.namedWindow("Canny Edge Detection", cv2.WINDOW_NORMAL)
cv2.createTrackbar('𝜏1', "Canny Edge Detection",0, 1000, upper_threshold)
cv2.createTrackbar('𝜏2', "Canny Edge Detection",0, 1000, lower_threshold)

temp_low = 0
temp_high = 0
cpy2 = circle_img.copy()
while True:
    cv2.imshow("Canny Edge Detection", cpy2)
    low_thresh = getLowerThreshold()
    high_thresh = getUpperThreshold()
    if temp_low != low_thresh or temp_high != high_thresh: # checking if either high or low threshold have changed
        temp_low = low_thresh
        temp_high = high_thresh
        cpy2 = cv2.Canny(circle_img, low_thresh, high_thresh, (3,3)) # applying .Canny() edge detection to image with a 3x3 kernel
        
    if cv2.waitKey(1) == 27:
        break 
cv2.destroyAllWindows()

# %%
import cv2
circle_img = cv2.imread('circle.jpg')
def upper_threshold(x):
    pass

def lower_threshold(x):
    pass

def getUpperThreshold():
    return int(cv2.getTrackbarPos('𝜏1', "Canny Edge Detection"))

def getLowerThreshold():
    return int(cv2.getTrackbarPos('𝜏2', "Canny Edge Detection"))

cv2.namedWindow("Canny Edge Detection", cv2.WINDOW_NORMAL)
cv2.createTrackbar('𝜏1', "Canny Edge Detection",0, 1000, upper_threshold)
cv2.createTrackbar('𝜏2', "Canny Edge Detection",0, 1000, lower_threshold)

temp_low = 0
temp_high = 0
cpy2 = parliament_clock_img.copy()
while True:
    cv2.imshow("Canny Edge Detection", cpy2)
    low_thresh = getLowerThreshold()
    high_thresh = getUpperThreshold()
    if temp_low != low_thresh or temp_high != high_thresh: # checking if either high or low threshold have changed
        temp_low = low_thresh
        temp_high = high_thresh
        cpy2 = cv2.Canny(parliament_clock_img, low_thresh, high_thresh, (3,3)) # applying .Canny() edge detection to image with a 3x3 kernel
        
    if cv2.waitKey(1) == 27:
        break 
cv2.destroyAllWindows()

# %%
def upper_threshold(x):
    pass

def lower_threshold(x):
    pass

def getUpperThreshold():
    return int(cv2.getTrackbarPos('𝜏1', "Canny Edge Detection"))

def getLowerThreshold():
    return int(cv2.getTrackbarPos('𝜏2', "Canny Edge Detection"))

cv2.namedWindow("Canny Edge Detection", cv2.WINDOW_NORMAL)
cv2.createTrackbar('𝜏1', "Canny Edge Detection",0, 1000, upper_threshold)
cv2.createTrackbar('𝜏2', "Canny Edge Detection",0, 1000, lower_threshold)

temp_low = 0
temp_high = 0
cpy2 = concentric_circles_img.copy()
while True:
    cv2.imshow("Canny Edge Detection", cpy2)
    low_thresh = getLowerThreshold()
    high_thresh = getUpperThreshold()
    if temp_low != low_thresh or temp_high != high_thresh: # checking if either high or low threshold have changed
        temp_low = low_thresh
        temp_high = high_thresh
        cpy2 = cv2.Canny(concentric_circles_img, low_thresh, high_thresh, (3,3)) # applying .Canny() edge detection to image with a 3x3 kernel
        
    if cv2.waitKey(1) == 27:
        break 
cv2.destroyAllWindows()
